# %%
import pandas as pd
import os

# %%
# dirname = os.path.dirname(__file__)
path = os.path.join('2018/')

# %%
df = pd.concat([pd.read_csv(f) for f in os.scandir(path)], ignore_index = True)

# %%
len(df)
# Out:
# 17902231

# %%
df2 = df.loc[df['birth year'] != 1969]

# %%
len(df2)
# Out:
# 16215942

# %%
df2 = df2.loc[df2['birth year']>1930]

# %%
len(df2)
# Out:
# 16201878

# %%
df2.sort_values(by=['tripduration'], ascending=False)
# Out:
#           tripduration                 starttime                  stoptime  \
# 476336        19510049  2018-01-22 18:20:27.5120  2018-09-05 14:47:56.8680
# 1428944       15962256  2018-02-21 14:15:10.9320  2018-08-25 09:12:47.3860
# 2187410       15020934  2018-03-15 18:21:38.8010  2018-09-05 14:50:33.4160
# 1264434       13931824  2018-02-21 15:30:02.3880  2018-08-01 22:27:07.0940
# 1264344       13586276  2018-02-12 15:38:54.2330  2018-07-19 22:36:50.5980
# ...                ...                       ...                       ...
# 8356587             61  2018-07-31 08:30:32.3770  2018-07-31 08:31:33.7180
# 13576117            61  2018-10-03 15:25:12.7270  2018-10-03 15:26:14.1830
# 10955628            61  2018-08-23 16:21:21.2590  2018-08-23 16:22:22.7740
# 13159530            61  2018-09-27 14:25:43.3370  2018-09-27 14:26:44.6290
# 1588815             61  2018-03-31 12:13:42.1150  2018-03-31 12:14:43.7490
#
#           start station id                start station name  \
# ...

# %%
df2 = df2.loc[df2['tripduration']>300]

# %%
len(df2)
# Out:
# 12993649

# %%
df2 = df2.loc[df2['tripduration']<86400]

# %%
len(df2)
# Out:
# 12990564

# %%
df2['month']=df2['starttime'].astype('datetime64[M]').dt.month

# %%
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5          1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
# 5              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
Jan = df2.loc[df2['month']==1]

# %%
Jan
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 2                  496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3                  306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4                  306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5                 1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
# ...                ...                       ...                       ...
# 17561006           705  2018-01-30 16:34:20.0470  2018-01-30 16:46:05.7640
# 17561007           491  2018-01-30 17:30:26.4000  2018-01-30 17:38:38.3360
# 17561012           806  2018-01-31 15:34:36.8370  2018-01-31 15:48:03.0280
# 17561013          1499  2018-01-31 15:45:09.8000  2018-01-31 16:10:09.4400
# 17561015           383  2018-01-31 18:34:50.2950  2018-01-31 18:41:13.7530
#
# ...

# %%
Jan = df2.loc[df2['month']==1]
Feb = df2.loc[df2['month']==2]
Mar = df2.loc[df2['month']==3]
Apr = df2.loc[df2['month']==4]
May = df2.loc[df2['month']==5]
Jun = df2.loc[df2['month']==6]
Jul = df2.loc[df2['month']==7]
Aug = df2.loc[df2['month']==8]
Sep = df2.loc[df2['month']==9]
Oct = df2.loc[df2['month']==10]
Nov = df2.loc[df2['month']==11]
Dec = df2.loc[df2['month']==12]

# %%
df2.to_csv('All2018.csv',index=False)

# %%
Jan.to_csv('Jan.csv',index=False)

# %%
Feb.to_csv('Feb.csv',index=False)
Mar.to_csv('Mar.csv',index=False)
Apr.to_csv('Apr.csv',index=False)
May.to_csv('May.csv',index=False)
Jun.to_csv('Jun.csv',index=False)
Jul.to_csv('Jul.csv',index=False)
Aug.to_csv('Aug.csv',index=False)
Sep.to_csv('Sep.csv',index=False)
Oct.to_csv('Oct.csv',index=False)
Nov.to_csv('Nov.csv',index=False)
Dec.to_csv('Dec.csv',index=False)

# %%
stations = df2['start station name'].value_counts()
top10starting = stations.head(10)
bottom10starting = stations.tail(10)

# %%
l = bottom10starting.index.to_list()

# %%
df3 = df2[~df2['start station name'].isin(l)]

# %%
stations2 = df3['start station name'].value_counts()
top10starting2 = stations2.head(10)
bottom10starting2 = stations2.tail(10)

# %%
bottom10starting2
# Out:
# Bressler                49
# MLK Light Rail          42
# Wyckoff St & Bond St    38
# NJCU                    37
# Bayside Park            33
# West Side Light Rail    30
# NYCBS Depot - RIS       28
# Bethune Center          20
# Columbia Park           13
# Danforth Light Rail     11
# Name: start station name, dtype: int64

# %%
df3.to_csv('All2018clean.csv',index=False)
